# %%
import pandas as pd

data  = pd.read_csv('../home_insight.csv')
data1 = pd.read_csv('../home_insight2.csv')
data2 = pd.read_csv('../home_insight3.csv')

pd.options.display.max_columns = None

# %% [markdown]
# Number of player assignation to specific positions occured based on their speed

# %%
display(data)
# Out:
#     # LBv     LBh     LBs      CBv     CBh     CBs     RBv     RBh     RBs  \
# 0  4056.0   686.0   626.0   8182.0  1484.0  1534.0  4061.0   631.0   789.0
# 1   742.0   165.0   113.0   1602.0   292.0   256.0   759.0   124.0   137.0
# 2  2317.0   460.0   525.0   6616.0  1506.0  1461.0  2926.0   656.0   600.0
# 3  1611.0   339.0   461.0   6697.0  1605.0  1729.0  1593.0   365.0   389.0
# 4  4686.0   967.0  1055.0   7132.0  1339.0  1585.0  3492.0   659.0   725.0
# 5  3329.0   802.0   859.0   9070.0  1700.0  1896.0  3779.0   614.0   777.0
# 6  3193.0   768.0   738.0   8885.0  2018.0  2098.0  2761.0   649.0   629.0
# 7  3122.0   626.0   935.0   6996.0  1536.0  1733.0  3329.0   596.0   696.0
# 8  4019.0  1009.0  1056.0  10133.0  2581.0  2420.0  4188.0  1001.0  1256.0
# 9  3200.0   711.0   914.0  10819.0  1943.0  2168.0  3383.0   539.0   782.0
#
#       LMv    LMh    LMs     CMv     CMh     CMs     RMv    RMh    RMs    ACMv  \
# ...

# %% [markdown]
# Number of player role assignation occured

# %%
display(data1)
# Out:
#      # LB       CB      RB      LM      CM      RM     ACM     LF      CF  \
# 0  4408.0  10901.0  4288.0  4129.0  9884.0  3455.0  1666.0  984.0  6237.0
#
#        RF
# 0  1262.0

# %% [markdown]
# Avrg number of player role assignation occured

# %%
display(data2)
# Out:
#      # LB       CB      RB      LM       CM      RM     ACM      LF      CF  \
# 0  4417.0  13250.0  4153.0  4096.0  11205.0  4521.0  2086.0  1408.0  7375.0
#
#        RF
# 0  1856.0
